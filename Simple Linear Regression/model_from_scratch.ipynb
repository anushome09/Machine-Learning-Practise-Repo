# %% [markdown]
# A User-Defined Class to build the simple linear regression model from scratch using formulas.

# %%
class my_simple_linear_regression:
    def __init__(self):
        # co-efficient
        self.m = None
        # intercept
        self.b = None
    
    def model_fit(self, X_train, X_test):
        
        num = 0
        den = 0
        
        for i in range(X_train.shape[0]):
           num = num + (X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean())
           den = den + (X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean())
           
        self.m = num / den
        
        self.b = y_train.mean() - (self.m * X_train.mean())
        
        print("The co-efficient of the model: ", self.m)
        print("The co-intercept of the model: ", self.b)
    
    def predict(self, X_test):
        return self.m * X_test + self.b

# %%
import pandas as pd
import numpy as np

# %%
# Loading the dataset
data = pd.read_csv('(data) placement details.csv')
data
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
# Separating the independent and dependent variables
X = data.iloc[:,0].values # converting Pandas series to Numpy array
y = data.iloc[:, 1].values

# %%
# Spliting the dataset into train and test dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

print("Shape of Independent Variable Training Set: ", X_train.shape)
print("Shape of Dependent Variable Training Set: ", y_train.shape)

print("Shape of Independent Variable Testing Set: ", X_test.shape)
print("Shape of Dependent Variable Testing Set: ", y_test.shape)
# Out:
# Shape of Independent Variable Training Set:  (160,)
# Shape of Dependent Variable Training Set:  (160,)
# Shape of Independent Variable Testing Set:  (40,)
# Shape of Dependent Variable Testing Set:  (40,)

# %%
# Creating an object for my_simple_linear_regression class
lr = my_simple_linear_regression()

# %%
# Calculating the value of co-efficient and intercept 
lr.model_fit(X_train, y_train)
# Out:
# The co-efficient of the model:  0.5579519734250721
# The co-intercept of the model:  -0.8961119222429152

# %%
# Testing with the Test Dataset
print("Predicted Value: ", lr.predict(X_test[0]))
print("Actual Value: ", y_test[0])
# Out:
# Predicted Value:  3.891116009744203
# Actual Value:  4.1
