# %%
import pandas as pd

# %%
df = pd.read_csv('/Machine Learning Practise Repo/Data Preprocessing/Data/EducationData.csv')
df.head()
# Out:
#                   Job_Title Education_Level  Years_Experience
# 0              Data Analyst        Bachelor                 2
# 1         Software Engineer        Bachelor                 4
# 2  Senior Software Engineer          Master                 8
# 3     IT Support Specialist       Associate                 3
# 4      System Administrator        Bachelor                 6
